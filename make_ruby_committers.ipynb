# %%
require 'open-uri'
require 'pycall/import'
include PyCall::Import

pyimport :pandas, as: :pd
pyimport :numpy, as: :np
pyblt = PyCall::builtins
Dict = PyCall::Dict
List = PyCall::List
# Out:
# <class 'list'>

# %%
def read_committers_log(file)
    committers = File.read(file).split("\n").map do |e|
        commits, id = e.split("\t")
        user, addr = id.split(" <")
        [commits.to_i, user, addr.chop]
    end
    pd.DataFrame.new(data: committers, columns:[:commits, :author, :addr])
end
# Out:
# :read_committers_log

# %%
df = read_committers_log('ruby_committers.log')
# Out:
#      commits          author                                          addr
# 0      16567            nobu     nobu@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
# 1       4746             akr      akr@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
# 2       4340             svn      svn@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
# 3       2728          naruse   naruse@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
# 4       2562            matz     matz@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
# ..       ...             ...                                           ...
# 279        1         ujihisa              ujihisa@users.noreply.github.com
# 280        1          y-yagi                      yuuji.yaginuma@gmail.com
# 281        1  yuuji.yaginuma                      yuuji.yaginuma@gmail.com
# 282        1         zsombor  zsombor@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
# 283        1  Étienne Barrié                      etienne.barrie@gmail.com
#
# [284 rows x 3 columns]

# %%
df.author.unique().size
# Out:
# 267

# %%
addr_join = proc {|s| s.tolist.to_a.join(',')}
df_uniq_author = df.groupby(:author).agg(Dict.new({commits: :sum, addr: addr_join}))
    .sort_values(:commits, ascending: false).reset_index
# Out:
#              author  commits                                              addr
# 0              nobu    16567         nobu@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
# 1               akr     4746          akr@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
# 2               svn     4340          svn@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
# 3            naruse     2728       naruse@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
# 4              matz     2562         matz@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
# ..              ...      ...                                               ...
# 262      Yaw Boakye        1                               wheresyaw@gmail.com
# 263      Will Binns        1                                      will@trek.io
# 264   Tomoki Aonuma        1                                      uasi@uasi.jp
# 265  Thomas Leitner        1                                  t_leitner@gmx.at
# 266     (no author)        1  (no author)@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
#
# [267 rows x 3 columns]

# %%
addr_user = proc do |df|
    df.addr.tolist.map do |addrs|
        addrs.split(',').map do |addr|
            user, domain = addr.split('@')
            if user == 'mail'
                domain.split('.')[0]
            elsif ['svn',  'svn-admin'].include?(user)
                'matzbot'
            elsif domain == 'users.noreply.github.com'
                sp = user.split('+')
                if sp.size == 2
                    sp[1]
                else
                    sp[0]
                end
            else
                user
            end
        end.uniq.join(',')
    end
end

df_addr_user = df_uniq_author.assign(addr_user: addr_user)
# Out:
#              author  ...    addr_user
# 0              nobu  ...         nobu
# 1               akr  ...          akr
# 2               svn  ...      matzbot
# 3            naruse  ...       naruse
# 4              matz  ...         matz
# ..              ...  ...          ...
# 262      Yaw Boakye  ...    wheresyaw
# 263      Will Binns  ...         will
# 264   Tomoki Aonuma  ...         uasi
# 265  Thomas Leitner  ...    t_leitner
# 266     (no author)  ...  (no author)
#
# [267 rows x 4 columns]

# %%
max_author =  proc {|s| s.tolist.max_by{|e| e.size}}
df_uniq_addr_user = df_addr_user.groupby(:addr_user).agg(Dict.new({commits: :sum, addr: addr_join, author: max_author}))
    .sort_values(:commits, ascending: false).reset_index
# Out:
#                  addr_user  ...                  author
# 0                     nobu  ...        Nobuyoshi Nakada
# 1                      akr  ...            Tanaka Akira
# 2                  matzbot  ...                     svn
# 3                   naruse  ...             NARUSE, Yui
# 4                     matz  ...                    matz
# ..                     ...  ...                     ...
# 232  richard.schneeman+foo  ...                schneems
# 233          rafaelmfranca  ...  Rafael Mendonça França
# 234                pvalena  ...            Pavel Valena
# 235             poketo7878  ...              Pocket7878
# 236            (no author)  ...             (no author)
#
# [237 rows x 4 columns]

# %%
def check_github_user(user)
    open("https://github.com/#{user}/")
    true
rescue => e
    false
end

is_github_user = df_uniq_addr_user.addr_user.tolist.map do |e|
    sleep(1)
    check_github_user(e)
end
# Out:
# [true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, false, true, true, true, true, true, true, true, true, true, true, false, false, true, true, false, true, true, true, true, true, true, true, true, true, false, true, true, true, true, true, true, false, false, true, true, true, false, true, false, true, true, true, false, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, true, false, true, true, false, true, true, true, false, true, true, true, true, false, false, false, true, true, true, true, true, true, false, false, true, false, false, false, true, false, true, true, false, false, false, true, true, true, true, true, false, false, true, true, true, true, true, true, true, true, true, false, false, true, false, true, true, false, true, false, true, true, false, false, false, false, false, false, false, false, true, true, true, false, true, false, false, true, false, true, true, false, false, true, false, true, true, false, true, false, true, true, true, false, false, true, true, true, false, true, true, true, true, true, false, true, false, false, false, false, false, true, false, false, false, true, true, true, true, true, false, true, true, true, true, true, true, false, false, false, true, true, true, false, true, true, false, true, false, false, true, false, true, false, false, false, true, false, false]

# %%
df_github_user = df_uniq_addr_user.assign(is_github_user: is_github_user)
# Out:
#                  addr_user  commits  ...                  author is_github_user
# 0                     nobu    17733  ...        Nobuyoshi Nakada           True
# 1                      akr     4759  ...            Tanaka Akira           True
# 2                  matzbot     4686  ...                     svn           True
# 3                   naruse     2760  ...             NARUSE, Yui           True
# 4                     matz     2562  ...                    matz           True
# ..                     ...      ...  ...                     ...            ...
# 232  richard.schneeman+foo        1  ...                schneems          False
# 233          rafaelmfranca        1  ...  Rafael Mendonça França          False
# 234                pvalena        1  ...            Pavel Valena           True
# 235             poketo7878        1  ...              Pocket7878          False
# 236            (no author)        1  ...             (no author)          False
#
# [237 rows x 5 columns]

# %%
add_tmp_user = proc do |df|
    df.is_github_user.tolist.zip(df.addr_user.tolist).map do |is_github_user, addr_user|
        is_github_user ? addr_user : "XXXX_" + addr_user 
    end
end

df_tmp_user = df_github_user.assign(tmp_user: add_tmp_user)
# Out:
#                  addr_user  commits  ... is_github_user                    tmp_user
# 0                     nobu    17733  ...           True                        nobu
# 1                      akr     4759  ...           True                         akr
# 2                  matzbot     4686  ...           True                     matzbot
# 3                   naruse     2760  ...           True                      naruse
# 4                     matz     2562  ...           True                        matz
# ..                     ...      ...  ...            ...                         ...
# 232  richard.schneeman+foo        1  ...          False  XXXX_richard.schneeman+foo
# 233          rafaelmfranca        1  ...          False          XXXX_rafaelmfranca
# 234                pvalena        1  ...           True                     pvalena
# 235             poketo7878        1  ...          False             XXXX_poketo7878
# 236            (no author)        1  ...          False            XXXX_(no author)
#
# [237 rows x 6 columns]

# %%
df_mod_drop = df_tmp_user.drop(columns: [:addr_user])
# Out:
#      commits  ...                    tmp_user
# 0      17733  ...                        nobu
# 1       4759  ...                         akr
# 2       4686  ...                     matzbot
# 3       2760  ...                      naruse
# 4       2562  ...                        matz
# ..       ...  ...                         ...
# 232        1  ...  XXXX_richard.schneeman+foo
# 233        1  ...          XXXX_rafaelmfranca
# 234        1  ...                     pvalena
# 235        1  ...             XXXX_poketo7878
# 236        1  ...            XXXX_(no author)
#
# [237 rows x 5 columns]

# %%
df_tmp_out = df_mod_drop.reindex(columns: [:commits, :tmp_user, :author, :is_github_user, :addr])
    .sort_values([:commits, :tmp_user], ascending: [false, true]).reset_index(drop: true)
# Out:
#      commits  ...                                               addr
# 0      17733  ...  nobu@b2dd03c8-39d4-4d8f-98ff-823fe69b080e,nobu...
# 1       4759  ...  akr@b2dd03c8-39d4-4d8f-98ff-823fe69b080e,akr@f...
# 2       4686  ...  svn@b2dd03c8-39d4-4d8f-98ff-823fe69b080e,svn@b...
# 3       2760  ...  naruse@b2dd03c8-39d4-4d8f-98ff-823fe69b080e,na...
# 4       2562  ...          matz@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
# ..       ...  ...                                                ...
# 232        1  ...                                       uasi@uasi.jp
# 233        1  ...                   ujihisa@users.noreply.github.com
# 234        1  ...                                       will@trek.io
# 235        1  ...         473530+ybiquitous@users.noreply.github.com
# 236        1  ...       zsombor@b2dd03c8-39d4-4d8f-98ff-823fe69b080e
#
# [237 rows x 5 columns]

# %%
df_tmp_out.to_csv("ruby_committers_tmp.csv", index: false)
